# %% [markdown]
# # Classes and Objects

# %% [markdown]
# ### Object-Oriented Programming (OOP) is a programming paradigm that uses "objects" to design applications and computer programs. OOP allows for modeling real-world scenarios using classes and objects.

# %%
### A class is a blue print for creating objects: attributes, methods

class Car:
    pass

audi = Car()
bmw = Car()

print(type(audi))
print(type(bmw))
# Out:
# <class '__main__.Car'>
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)

# %%
### Instance Variable and Methods

class Dog:
    ## constructor
    def __init__(self, name, age):  ## number of instance variables defined in constructor that much only we have
        self.name = name  ## self useful for accessing instance variable
        self.age = age

## create objects
dog1 = Dog("Buddy", 3)
print(dog1)
print(dog1.name)
print(dog1.age)
## we can't use self keyword outside class
# Out:
# ...
# Buddy
# 3

# %%
dog2 = Dog("Lucy", 4)
print(dog2.name)
print(dog2.age)
# Out:
# Lucy
# 4

# %%
## Define a class with instance methods

class Dog:
    def __init__(self, name, age):  
        self.name = name  
        self.age = age

    def bark(self):     ## instance methods
        print(f"{self.name} says woof")

dog1 = Dog("Buddy", 3)
dog1.bark()
dog2 = Dog("Lucy", 4)
dog2.bark()
# Out:
# Buddy says woof
# Lucy says woof

# %%
### Modelling a Bank Account

## Define a class for bank account

class BankAccount:
    def __init__(self, owner, balance = 0):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} deposited now New balance is {self.balance}")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"{amount} withdrawn now New balance is {self.balance}")
        else:
            print("Insufficient Money")

    def getBalance(self):
        print("Balance is ", self.balance)

# %%
## create an account

account_1 = BankAccount("Aditya", 50000)
print(account_1.balance)
# Out:
# 50000

# %%
## Call instance methods

# deposit
account_1.deposit(35000)
# Out:
# 35000 deposited now New balance is 85000

# %%
# withdraw
account_1.withdraw(22000)
# Out:
# 22000 withdrawn now New balance is 63000

# %%
# get balance
account_1.getBalance()
# Out:
# Balance is  63000

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Object-Oriented Programming (OOP) allows us to model real-world scenarios using classes and objects. Here, we learned how to create classes and objects, define instance variables and methods, and use to perform various operations. These concepts are fundamental and necessary to write effective and maintainable Python code.
